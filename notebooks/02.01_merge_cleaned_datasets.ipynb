# %% [markdown]
# - Version: 1.0
# - last updated: 2023-12-08
# - Short description: This notebook is used to merge the cleaned datasets.

# %% [markdown]
# ## Install and Import

# %%
# Import modules
import warnings
from datetime import date
import pandas as pd

# %% [markdown]
# ## Notebook Details

# %%
# parameters for logging and notebook exports
notebook_name = "02.01_merge_cleaned_datasets"  # only file name without extension

# %% [markdown]
# ## Configuration

# %%
# Pandas
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Warnings
warnings.filterwarnings("ignore")

# %%
# Constants
ROOT_PATH = "../"
PATH_DATA = "data/"
PATH_DATA_RAW = "data/raw/"
PATH_DATA_INT = "data/interim/"
PATH_DATA_PRO = "data/processed/"
PATH_LOG = "logs/"
PATH_MOD = "models/"
PATH_REP = "reports/"
PATH_FIG = "reports/figures/"
PATH_HTML = "reports/html/"

# %% [markdown]
# ## Load Data

# %%
def load_data(path):
    return pd.read_parquet(ROOT_PATH + path)

file = "donor_information_cleaned.parquet"
df_di = pd.read_parquet(ROOT_PATH + PATH_DATA_INT + file)

file = "group_weights_cleaned.parquet"
df_gw = pd.read_parquet(ROOT_PATH + PATH_DATA_INT + file)

file = "papq_wide_cleaned.parquet"
df_papq_wide = pd.read_parquet(ROOT_PATH + PATH_DATA_INT + file)

# %% [markdown]
# ## Main Part

# %%
# Merge the datasets on the "name" column
merged_data = pd.merge(df_di, df_gw, on="name", how="inner")

# Display the first few rows of the merged dataset
merged_data.head()
# Out:
#     donor_id        name    age sex apo_e4_allele  education_years  \
# 0  326765665  H14.09.078     87   M             N               16
# 1  326765656  H14.09.069  95-99   M             N               17
# 2  326765654  H14.09.067     85   M             Y               10
# 3  467056391  H15.09.103  90-94   F             N               11
# 4  309335447  H14.09.010   100+   M             Y               16
#
#    age_at_first_tbi longest_loc_duration  cerad  num_tbi_w_loc  \
# 0                 0       Unknown or N/A      0              0
# 1                12              1-2 min      2              1
# 2                72             < 10 sec      3              1
# 3                87             < 10 sec      0              1
# 4                 0       Unknown or N/A      3              0
#
#   dsm_iv_clinical_diagnosis  control_set         nincds_arda_diagnosis  \
# 0               No Dementia           31                   No Dementia
# 1               No Dementia           26                   No Dementia
# 2                  Vascular           25        Dementia, Type Unknown
# 3               No Dementia           52                   No Dementia
# 4  Alzheimer's Disease Type           28  Possible Alzheimer'S Disease
#
#   ever_tbi_w_loc   race      hispanic act_demented  braak  nia_reagan age_bin  \
# 0              N  White  Not Hispanic  No Dementia      1           1   87-89
# 1              Y  White  Not Hispanic  No Dementia      5           2   95-99
# 2              Y  White  Not Hispanic     Dementia      4           2   81-86
# 3              Y  White  Not Hispanic  No Dementia      4           0   90-94
# 4              N  White  Not Hispanic     Dementia      4           2    100+
#
#    age_clean age_at_first_tbi_bin education_years_stages_bin  \
# 0       87.0                   NA                16-18 years
# 1       97.0   early_years (1-30)                16-18 years
# 2       85.0   late_years (61-90)                 5-11 years
# 3       92.0   late_years (61-90)                 5-11 years
# 4      101.0                   NA                16-18 years
#
#   education_years_quartiles_bin longest_loc_duration_bin  \
# 0                   14-16 years           Unknown or N/A
# 1                   16-21 years           10 sec - 5 min
# 2                    5-12 years                 < 10 sec
# 3                    5-12 years                 < 10 sec
# 4                   14-16 years           Unknown or N/A
#
#    longest_loc_duration_clean  act_demented_clean  sex_clean  \
# 0                         0.0                   0          1
# 1                        90.0                   0          1
# 2                         5.5                   1          1
# 3                         5.5                   0          0
# 4                         0.0                   1          1
#
#    apo_e4_allele_clean  ever_tbi_w_loc_clean  group_weight
# 0                    0                     0         47.75
# 1                    0                     1         11.54
# 2                    1                     1          5.66
# 3                    0                     1         17.31
# 4                    1                     0         12.31

# %%
merged_data.shape
# Out:
# (107, 31)

# %%
# Merge the datasets
merged_data = pd.merge(merged_data, df_papq_wide, on="donor_id", how="inner")

# Display the first few rows of the merged dataset
merged_data.head()
# Out:
#     donor_id        name    age sex apo_e4_allele  education_years  \
# 0  326765665  H14.09.078     87   M             N               16
# 1  326765656  H14.09.069  95-99   M             N               17
# 2  326765654  H14.09.067     85   M             Y               10
# 3  467056391  H15.09.103  90-94   F             N               11
# 4  309335447  H14.09.010   100+   M             Y               16
#
#    age_at_first_tbi longest_loc_duration  cerad  num_tbi_w_loc  \
# 0                 0       Unknown or N/A      0              0
# 1                12              1-2 min      2              1
# 2                72             < 10 sec      3              1
# 3                87             < 10 sec      0              1
# 4                 0       Unknown or N/A      3              0
#
#   dsm_iv_clinical_diagnosis  control_set         nincds_arda_diagnosis  \
# 0               No Dementia           31                   No Dementia
# 1               No Dementia           26                   No Dementia
# 2                  Vascular           25        Dementia, Type Unknown
# 3               No Dementia           52                   No Dementia
# 4  Alzheimer's Disease Type           28  Possible Alzheimer'S Disease
#
#   ever_tbi_w_loc   race      hispanic act_demented  braak  nia_reagan age_bin  \
# 0              N  White  Not Hispanic  No Dementia      1           1   87-89
# 1              Y  White  Not Hispanic  No Dementia      5           2   95-99
# 2              Y  White  Not Hispanic     Dementia      4           2   81-86
# 3              Y  White  Not Hispanic  No Dementia      4           0   90-94
# 4              N  White  Not Hispanic     Dementia      4           2    100+
#
#    age_clean age_at_first_tbi_bin education_years_stages_bin  \
# 0       87.0                   NA                16-18 years
# 1       97.0   early_years (1-30)                16-18 years
# 2       85.0   late_years (61-90)                 5-11 years
# 3       92.0   late_years (61-90)                 5-11 years
# 4      101.0                   NA                16-18 years
#
#   education_years_quartiles_bin longest_loc_duration_bin  \
# 0                   14-16 years           Unknown or N/A
# 1                   16-21 years           10 sec - 5 min
# 2                    5-12 years                 < 10 sec
# 3                    5-12 years                 < 10 sec
# 4                   14-16 years           Unknown or N/A
#
#    longest_loc_duration_clean  act_demented_clean  sex_clean  \
# 0                         0.0                   0          1
# 1                        90.0                   0          1
# 2                         5.5                   1          1
# 3                         5.5                   0          0
# 4                         0.0                   1          1
#
#    apo_e4_allele_clean  ever_tbi_w_loc_clean  group_weight  ihc_a_syn_FWM  \
# 0                    0                     0         47.75      -1.000000
# 1                    0                     1         11.54       0.000034
# 2                    1                     1          5.66       0.000440
# 3                    0                     1         17.31       0.000132
# 4                    1                     0         12.31       0.000061
#
#    ihc_a_syn_HIP  ihc_a_syn_PCx  ihc_a_syn_TCx  ihc_tau2_ffpe_FWM  \
# 0       0.000046      -1.000000       0.000056          -1.000000
# 1       0.000071       0.000063       0.000093           0.001563
# 2       0.001930       0.001507       0.003973           0.001519
# 3       0.000056       0.000037       0.000046           0.000770
# 4       0.000099       0.000061       0.000062           0.003454
#
#    ihc_tau2_ffpe_HIP  ihc_tau2_ffpe_PCx  ihc_tau2_ffpe_TCx  ihc_at8_ffpe_FWM  \
# 0           0.003905          -1.000000           0.003677         -1.000000
# 1           0.011440           0.003407           0.006103          0.005634
# 2           0.010791           0.002416           0.003542          0.001692
# 3           0.002497           0.000831           0.000965          0.001412
# 4           0.005172           0.005010           0.004301          0.003673
#
#    ihc_at8_ffpe_HIP  ihc_at8_ffpe_PCx  ihc_at8_ffpe_TCx  ihc_at8_FWM  \
# 0          0.013143         -1.000000          0.001854    -1.000000
# 1          0.036654          0.017135          0.026569     0.002274
# 2          0.019839          0.001893          0.021183     0.000047
# 3          0.026111          0.001490          0.003760     0.000095
# 4          0.016716          0.004296          0.023869     0.047266
#
#    ihc_at8_HIP  ihc_at8_PCx  ihc_at8_TCx  ihc_ptdp_43_ffpe_FWM  \
# 0     0.012439    -1.000000     0.000061             -1.000000
# 1     0.056922     0.014112     0.009599              0.001702
# 2     0.038885     0.000161     0.000189              0.000969
# 3     0.011910     0.000076     0.000054              0.001028
# 4     0.050732     0.003227     0.001401              0.002526
#
#    ihc_ptdp_43_ffpe_HIP  ihc_ptdp_43_ffpe_PCx  ihc_ptdp_43_ffpe_TCx  \
# 0              0.001035             -1.000000              0.001987
# 1              0.000888              0.001886              0.001137
# 2              0.001444              0.001825              0.001821
# 3              0.001730              0.000984              0.000881
# 4              0.003779              0.003384              0.002607
#
#    ihc_a_beta_ffpe_FWM  ihc_a_beta_ffpe_HIP  ihc_a_beta_ffpe_PCx  \
# 0            -1.000000             0.008041            -1.000000
# 1             0.003060             0.010088             0.033776
# 2             0.003821             0.014584             0.016357
# 3             0.003223             0.009737             0.006950
# 4             0.004146             0.005239             0.014006
#
#    ihc_a_beta_ffpe_TCx  ihc_a_beta_FWM  ihc_a_beta_HIP  ihc_a_beta_PCx  \
# 0             0.006379       -1.000000        0.007813       -1.000000
# 1             0.030330        0.012777        0.016031        0.061333
# 2             0.022213        0.010000        0.016216        0.066307
# 3             0.011834        0.000432        0.002754        0.009260
# 4             0.032423        0.008276        0.013382        0.041812
#
#    ihc_a_beta_TCx  ihc_iba1_ffpe_FWM  ihc_iba1_ffpe_HIP  ihc_iba1_ffpe_PCx  \
# 0        0.001810          -1.000000           0.045469          -1.000000
# 1        0.055102           0.055185           0.049652           0.047596
# 2        0.065810           0.050263           0.075951           0.049983
# 3        0.009037           0.081018           0.058660           0.065651
# 4        0.032829           0.030934           0.055457           0.032725
#
#    ihc_iba1_ffpe_TCx  ihc_gfap_ffpe_FWM  ihc_gfap_ffpe_HIP  ihc_gfap_ffpe_PCx  \
# 0           0.025448          -1.000000           0.064207          -1.000000
# 1           0.050715           0.089000           0.048178           0.046832
# 2           0.048856           0.032765           0.029312           0.025223
# 3           0.086925           0.030904           0.064947           0.016388
# 4           0.057374           0.024208           0.051301           0.032866
#
#    ihc_gfap_ffpe_TCx  ptau_ng_per_mg_FWM  ptau_ng_per_mg_HIP  \
# 0          -1.000000           -1.000000            0.746922
# 1           0.041647            1.395498            4.712879
# 2           0.022923            0.332819            1.816172
# 3           0.022866            1.624779            2.540756
# 4           0.030665            0.345002            2.243292
#
#    ptau_ng_per_mg_PCx  ptau_ng_per_mg_TCx  vegf_pg_per_mg_FWM  \
# 0           -1.000000            0.121403               -1.00
# 1            1.719367            1.355935                1.24
# 2            0.734323            0.672854                3.42
# 3            2.397251            2.262960                0.68
# 4            0.706289            0.703624                2.14
#
#    vegf_pg_per_mg_HIP  vegf_pg_per_mg_PCx  vegf_pg_per_mg_TCx  \
# 0                0.00               -1.00                1.64
# 1                0.76                1.18                2.08
# 2                0.50                1.36                2.48
# 3                1.36                0.68                1.87
# 4                0.00                3.64                2.08
#
#    ab42_over_ab40_ratio_FWM  ab42_over_ab40_ratio_HIP  \
# 0                 -1.000000                  0.182779
# 1                394.006795                342.148288
# 2                869.786538                129.829985
# 3                  0.445030                  1.525649
# 4               1000.000000                205.671818
#
#    ab42_over_ab40_ratio_PCx  ab42_over_ab40_ratio_TCx  tnf_a_pg_per_mg_FWM  \
# 0                 -1.000000                 27.658229                 -1.0
# 1                230.613801                211.125225                  0.0
# 2                398.561763                169.806888                  0.0
# 3                  1.307275                  0.479263                  0.5
# 4                556.536067                290.443666                  0.0
#
#    tnf_a_pg_per_mg_HIP  tnf_a_pg_per_mg_PCx  tnf_a_pg_per_mg_TCx  \
# 0                 8.10                -1.00                 0.80
# 1                13.08                 2.70                 1.14
# 2                11.26                 2.68                 0.00
# 3                28.05                 0.00                 1.62
# 4                 8.70                 0.30                 1.98
#
#    tau_ng_per_mg_FWM  tau_ng_per_mg_HIP  tau_ng_per_mg_PCx  tau_ng_per_mg_TCx  \
# 0          -1.000000           1.281790          -1.000000           1.668690
# 1           1.088977           1.405920           1.049501           1.467668
# 2           0.904703           1.139455           1.014441           1.569319
# 3           1.591404           1.483437           1.512623           1.580459
# 4           0.980690           1.347626           1.192077           1.331770
#
#    il_10_pg_per_mg_FWM  il_10_pg_per_mg_HIP  il_10_pg_per_mg_PCx  \
# 0                -1.00                 0.00                -1.00
# 1                 0.00                 0.66                 0.18
# 2                 0.46                 2.48                 0.46
# 3                 0.42                 0.78                 0.00
# 4                 0.34                 0.38                 0.26
#
#    il_10_pg_per_mg_TCx  isoprostane_pg_per_mg_FWM  isoprostane_pg_per_mg_HIP  \
# 0                 0.12                       -1.0                       -1.0
# 1                 0.32                       -1.0                       -1.0
# 2                 1.20                       -1.0                       -1.0
# 3                 3.19                       -1.0                       -1.0
# 4                 0.00                       -1.0                       -1.0
#
#    isoprostane_pg_per_mg_PCx  isoprostane_pg_per_mg_TCx  il_6_pg_per_mg_FWM  \
# 0                  -1.000000                   2.664223               -1.00
# 1                   2.511954                  -1.000000                4.83
# 2                   2.068608                   2.760603                0.50
# 3                   2.674447                   4.945019                0.64
# 4                   3.712133                   2.345858                0.68
#
#    il_6_pg_per_mg_HIP  il_6_pg_per_mg_PCx  il_6_pg_per_mg_TCx  \
# 0               74.04               -1.00                0.94
# 1               22.88                3.12                2.70
# 2               17.60                0.94                0.10
# 3              164.21                0.22                1.15
# 4               20.84                0.62                0.32
#
#    il_1b_pg_per_mg_FWM  il_1b_pg_per_mg_HIP  il_1b_pg_per_mg_PCx  \
# 0                 -1.0                 0.24                 -1.0
# 1                  0.0                 0.28                  0.0
# 2                  0.0                 0.10                  0.0
# 3                  0.0                 0.00                  0.0
# 4                  0.0                 0.10                  0.0
#
#    il_1b_pg_per_mg_TCx  ptau_over_tau_ratio_FWM  ptau_over_tau_ratio_HIP  \
# 0                  0.0                -1.000000                 0.582718
# 1                  0.0                 1.281475                 3.352169
# 2                  0.0                 0.367877                 1.593896
# 3                  0.0                 1.020972                 1.712750
# 4                  0.0                 0.351795                 1.664625
#
#    ptau_over_tau_ratio_PCx  ptau_over_tau_ratio_TCx  il_4_pg_per_mg_FWM  \
# 0                -1.000000                 0.072753               -1.00
# 1                 1.638270                 0.923870                3.37
# 2                 0.723870                 0.428755                0.52
# 3                 1.584831                 1.431837                0.30
# 4                 0.592486                 0.528337                0.00
#
#    il_4_pg_per_mg_HIP  il_4_pg_per_mg_PCx  il_4_pg_per_mg_TCx  \
# 0                 0.0               -1.00                1.60
# 1                 0.0                0.30                0.00
# 2                 0.0                3.02                0.00
# 3                 0.0                0.30                2.86
# 4                 0.0                1.00                0.00
#
#    rantes_pg_per_mg_FWM  rantes_pg_per_mg_HIP  rantes_pg_per_mg_PCx  \
# 0                 -1.00                 12.78                 -1.00
# 1                  7.02                 10.14                 13.38
# 2                 12.30                  7.58                 12.32
# 3                 34.62                 17.16                 43.04
# 4                 12.44                  6.72                 31.98
#
#    rantes_pg_per_mg_TCx  ab40_pg_per_mg_FWM  ab40_pg_per_mg_HIP  \
# 0                 81.88           -1.000000            0.545775
# 1                 19.10            1.333781            1.350075
# 2                 15.28            0.351000            1.918287
# 3                 62.78            0.379750            0.246837
# 4                 18.80            0.222125            2.125650
#
#    ab40_pg_per_mg_PCx  ab40_pg_per_mg_TCx  a_syn_pg_per_mg_FWM  \
# 0           -1.000000            0.157781            -1.000000
# 1            2.732625            2.165800             0.067883
# 2            1.250438            2.866500             0.060729
# 3            0.303800            0.493675             0.024101
# 4            0.977350            1.264900             0.105482
#
#    a_syn_pg_per_mg_HIP  a_syn_pg_per_mg_PCx  a_syn_pg_per_mg_TCx  \
# 0             0.296666            -1.000000             0.180000
# 1             0.467025             0.086297             0.570000
# 2             0.426804             0.135326             0.170000
# 3             0.075057             0.037077             0.024418
# 4             0.213645             0.090082             0.090000
#
#    ifn_g_pg_per_mg_FWM  ifn_g_pg_per_mg_HIP  ifn_g_pg_per_mg_PCx  \
# 0                -1.00                 1.94                -1.00
# 1                 0.95                 0.00                 0.28
# 2                 0.00                 0.00                 0.02
# 3                 0.28                 0.67                 0.00
# 4                 0.00                 0.00                 0.08
#
#    ifn_g_pg_per_mg_TCx  mcp_1_pg_per_mg_FWM  mcp_1_pg_per_mg_HIP  \
# 0                 0.84                -1.00                 0.58
# 1                 0.06                13.75                 2.50
# 2                 0.00                40.40                 4.54
# 3                 1.64                 5.76                 5.15
# 4                 0.06                11.94                 1.28
#
#    mcp_1_pg_per_mg_PCx  mcp_1_pg_per_mg_TCx  bdnf_pg_per_mg_FWM  \
# 0                -1.00                18.68           -1.000000
# 1                12.10                30.94            2.867955
# 2                29.30                20.86            3.507820
# 3                 2.20                17.59            3.472415
# 4                17.06                18.78            4.250960
#
#    bdnf_pg_per_mg_HIP  bdnf_pg_per_mg_PCx  bdnf_pg_per_mg_TCx  \
# 0            4.036190            -1.00000            0.180000
# 1            4.797790             8.21508            0.570000
# 2            5.060690             3.86952            0.170000
# 3           37.540205             7.85177            0.024418
# 4            4.036190             6.89792            0.090000
#
#    mip_1a_pg_per_mg_FWM  mip_1a_pg_per_mg_HIP  mip_1a_pg_per_mg_PCx  \
# 0                 -1.00                  3.70                 -1.00
# 1                  0.00                 39.32                  6.18
# 2                  5.62                 49.36                  6.14
# 3                  7.54                 21.59                 10.56
# 4                  6.36                 11.14                 10.70
#
#    mip_1a_pg_per_mg_TCx  il_7_pg_per_mg_FWM  il_7_pg_per_mg_HIP  \
# 0                 15.38               -1.00                0.60
# 1                  5.32                3.93                0.30
# 2                  4.28               34.48                0.04
# 3                 14.78               17.42                0.00
# 4                  4.04               15.54                0.16
#
#    il_7_pg_per_mg_PCx  il_7_pg_per_mg_TCx  ab42_pg_per_mg_FWM  \
# 0               -1.00               11.00           -1.000000
# 1               29.52               23.90          525.518875
# 2               38.06               19.08          305.295075
# 3               17.66               15.00            0.169000
# 4               15.42               14.82          284.863688
#
#    ab42_pg_per_mg_HIP  ab42_pg_per_mg_PCx  ab42_pg_per_mg_TCx  total_scan
# 0            0.099756           -1.000000            4.363950           2
# 1          461.925850          630.181038          457.255013           4
# 2          249.051238          498.376575          486.751444           4
# 3            0.376588            0.397150            0.236600           4
# 4          437.186300          543.930525          367.382194           4

# %%
merged_data.shape
# Out:
# (107, 148)

# %% [markdown]
# ## Exports

# %%
# Export
file = "features_merged"
merged_data.to_csv(ROOT_PATH + PATH_DATA_INT + f"{file}.csv")
merged_data.to_parquet(ROOT_PATH + PATH_DATA_INT + f"{file}.parquet")

# %% [markdown]
# ## Watermark

# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-12-08T16:01:47.514024+01:00
#
# Python implementation: CPython
# Python version       : 3.9.16
# IPython version      : 8.16.1
#
# Compiler    : Clang 14.0.6
# OS          : Darwin
# Release     : 22.6.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 4
# Architecture: 64bit

# %%
# %watermark --iversions
# Out:
# pandas: 2.1.1

# %% [markdown]
# -----

# %% [markdown]
# ## Snapshot

# %%
today = date.today()
output_file = f"{ROOT_PATH}{PATH_HTML}{today}_{notebook_name}.html"
input_file = f"{notebook_name}.ipynb"
print(input_file)
# !jupyter nbconvert --to html {input_file} --output {output_file}
# Out:
# 02.01_merge_cleaned_datasets.ipynb
# [NbConvertApp] Converting notebook 02.01_merge_cleaned_datasets.ipynb to html
# [NbConvertApp] Writing 312161 bytes to ../reports/html/2023-12-08_02.01_merge_cleaned_datasets.html
